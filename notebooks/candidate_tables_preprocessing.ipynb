# %% [markdown]
# # Candidate Tables Preprocessing
#
# To evaluate the model performance we also include some tables from other sources than wikipedia.

# %%
import pandas as pd
import numpy as np
import names

# %% [markdown]
# ## Titanic
#
# Link: https://www.kaggle.com/c/titanic

# %%
df = pd.read_csv('/home/mikexydas/Downloads/train.csv')
df = df.drop(['SibSp', 'Parch', 'Pclass', 'Embarked', 'Cabin'], axis=1)
df = df.dropna()

# We replace the column name with new random names since the current column includes family info.
df['Name'] = df['Name'].apply(lambda x: names.get_full_name())

df['Survived'] = df['Survived'].apply(lambda x: "Survived" if x==0 else "Died")
df['Age'] = df['Age'].apply(np.int64)

# %%
df.to_csv('../storage/datasets/random_datasets/titanic.csv', index=False)
display(df)
# Out:
#      PassengerId  Survived              Name     Sex  Age            Ticket  \
# 0              1  Survived        Allen Parr    male   22         A/5 21171
# 1              2      Died    Robert Gambrel  female   38          PC 17599
# 2              3      Died    Millie Garrett  female   26  STON/O2. 3101282
# 3              4      Died         Roy Fonua  female   35            113803
# 4              5  Survived      Elmer Miller    male   35            373450
# ..           ...       ...               ...     ...  ...               ...
# 885          886  Survived  Roxanna Thompson  female   39            382652
# 886          887  Survived      Joan Sanford    male   27            211536
# 887          888      Died      Patrick Howe  female   19            112053
# 889          890      Died   Herbert Metzler    male   26            111369
# 890          891  Survived   Shirley Merrell    male   32            370376
#
#         Fare
# 0     7.2500
# 1    71.2833
# ...

# %% [markdown]
# ## Student Performance
#
# Link: https://www.kaggle.com/spscientist/students-performance-in-exams

# %%
df = pd.read_csv('/home/mikexydas/Downloads/archive/StudentsPerformance.csv')
df = df.rename(columns = {"race/ethnicity":"ethnicity", 
                          "test preparation course": "test_preparation_course",
                          "math score": "math_score",
                          "reading score": "reading_score",
                          "writing score": "writing_score",
                          "parental level of education": "parental_level_of_education"})
df.insert(0, "student_id", df.index)
df = df[:300]

# %%
df.to_csv('../storage/datasets/random_datasets/student_performance.csv', index=False)
display(df)
# Out:
#      student_id  gender ethnicity parental_level_of_education         lunch  \
# 0             0  female   group B           bachelor's degree      standard
# 1             1  female   group C                some college      standard
# 2             2  female   group B             master's degree      standard
# 3             3    male   group A          associate's degree  free/reduced
# 4             4    male   group C                some college      standard
# ..          ...     ...       ...                         ...           ...
# 295         295    male   group B          associate's degree  free/reduced
# 296         296    male   group A            some high school      standard
# 297         297    male   group E          associate's degree      standard
# 298         298    male   group C                 high school  free/reduced
# 299         299    male   group D          associate's degree  free/reduced
#
# ...

# %% [markdown]
# ## Netflix Shows
#
# Link: https://www.kaggle.com/shivamb/netflix-shows

# %%
df = pd.read_csv('/home/mikexydas/Downloads/archive/netflix_titles.csv')
df = df.drop(['cast', 'listed_in', 'description'], axis=1)
df = df.dropna()
df.insert(0, "student_id", df.index)
df = df.sample(n=300)

# %%
df.to_csv('../storage/datasets/random_datasets/netflix_shows.csv', index=False)
display(df)
# Out:
#      show_id   type                                              title  \
# 6305   s6306  Movie                                      The Discovery
# 6644   s6645  Movie                                  The Mask of Zorro
# 5696   s5697  Movie                                               Solo
# 3605   s3606  Movie  Lessons from a School Shooting: Notes from Dun...
# 7294   s7295  Movie                                             U Turn
# ...      ...    ...                                                ...
# 3762   s3763  Movie                                        Love Jacked
# 1425   s1426  Movie                               Clouds of Sils Maria
# 4382   s4383  Movie                                        Nacho Libre
# 4635   s4636  Movie                       Once Upon a Time in the West
# 3516   s3517  Movie                                  Lady in the Water
#
#                 director                         country          date_added  \
# ...

# %% [markdown]
# ## Amazon Books
#
# Link: https://www.kaggle.com/sootersaalu/amazon-top-50-bestselling-books-2009-2019

# %%
df = pd.read_csv('/home/mikexydas/Downloads/archive/bestsellers with categories.csv')
df = df.rename(columns = {"User Rating":"Rating"})
df.insert(0, "BookId", df.index)
df = df.sample(300)

# %%
df.to_csv('../storage/datasets/random_datasets/books.csv', index=False)
display(df)
# Out:
#      BookId                                               Name  \
# 160     160                  Have a Little Faith: A True Story
# 203     203  Kitchen Confidential Updated Edition: Adventur...
# 274     274  Publication Manual of the American Psychologic...
# 75       75                                          Divergent
# 406     406     The House of Hades (Heroes of Olympus, Book 4)
# ..      ...                                                ...
# 489     489                   The Wonderful Things You Will Be
# 11       11  A Patriot's History of the United States: From...
# 505     505                              To Kill a Mockingbird
# 20       20                        All the Light We Cannot See
# 86       86  Dog Man: For Whom the Ball Rolls: From the Cre...
#
#                                  Author  Rating  Reviews  Price  Year  \
# 160                         Mitch Albom     4.8     1930      4  2009
# ...
